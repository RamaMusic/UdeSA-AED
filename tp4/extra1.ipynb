# %%
from graph import Graph
from tp4 import readGraph, processTime
import time as casio
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
def extra1(page_graph: Graph):
    print("--------------------")
    print("        Extra1      ")
    print("--------------------")
    
    start = casio.time()
    iterations = [100, 50, 25]
    k_values = [3, 4, 5]
    graph_y = []
    for i in range(len(iterations)):
        ans = page_graph.estimateKCycles(k_values[i], iterations[i])
        graph_y.append(ans)
    
    plt.figure()
    plt.bar(k_values, graph_y, edgecolor='black')
    plt.xlabel('k')
    plt.ylabel('Number of k-side polygons')
    plt.title('Number of k-side polygons in the graph')
    plt.yscale('log')
    plt.show()
        
    end = casio.time()
    
    processTime(start, end)
    
if __name__ == "__main__":
    page_graph = readGraph(path='web-Google.txt')
    extra1(page_graph)
# Out:
# Reading web-Google.txt...
# 100%|█████████▉| 5105039/5105040 [00:15<00:00, 336947.80it/s]
# Finished reading web-Google.txt
# --------------------
#         Extra1
# --------------------
# Counting k-cycles: 100%|██████████| 100/100 [08:11<00:00,  4.91s/it]
# Counting k-cycles: 100%|██████████| 50/50 [04:47<00:00,  5.75s/it]
# Counting k-cycles: 100%|██████████| 25/25 [10:01<00:00, 24.08s/it]
# Time elapsed: 23m 1.33s
